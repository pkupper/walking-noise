# %%
import pandas as pd

# %%
df_new = pd.read_csv('compiled_13591.out')
df_new
# Out:
#       TrainFirstMulThenAdd  TrainGaussStdMul  TrainGaussStdAdd  \
# 0                     True          0.599484         46.415888
# 1                     True          0.599484         46.415888
# 2                     True          0.599484         46.415888
# 3                     True          0.599484         46.415888
# 4                     True          0.599484         46.415888
# ...                    ...               ...               ...
# 9995                  True          0.007743          0.599484
# 9996                  True          0.007743          0.599484
# 9997                  True          0.007743          0.599484
# 9998                  True          0.007743          0.599484
# 9999                  True          0.007743          0.599484
#
#       InfFirstMulThenAdd  InfGaussStdMul  InfGaussStdAdd  Accuracy
# 0                  False    1.000000e-04    1.000000e-04     61.12
# 1                  False    7.742637e-03    1.000000e-04     61.05
# ...

# %%
df_old = pd.read_csv('compiled_12423.out')
df_old
# Out:
#       TrainFirstMulThenAdd  TrainGaussStdMul  TrainGaussStdAdd  \
# 0                     True      1.000000e+13          0.599484
# 1                     True      1.000000e+13          0.599484
# 2                     True      1.000000e+13          0.599484
# 3                     True      1.000000e+13          0.599484
# 4                     True      1.000000e+13          0.599484
# ...                    ...               ...               ...
# 9995                  True      1.668101e+09          0.599484
# 9996                  True      1.668101e+09          0.599484
# 9997                  True      1.668101e+09          0.599484
# 9998                  True      1.668101e+09          0.599484
# 9999                  True      1.668101e+09          0.599484
#
#       InfFirstMulThenAdd  InfGaussStdMul  InfGaussStdAdd  Accuracy
# 0                  False    1.000000e-04    1.000000e-04     66.69
# 1                  False    7.742637e-03    1.000000e-04     66.63
# ...
